# %%
#---------------------平文予測攻撃---------------------
from analysis_model_plain import *#平文予測攻撃用のライブラリをインポート

#変数など
#ROUND=31 #段数
ROUND=2 #段数
TRAIN_NUM=1000000#トレーニングデータ数
TEST_NUM=200000#テストデータ数
gpu_num="0"#使用するGPU

import time
start=time.time()#開始時間

#----------------------計算開始-----------------------------

aModel=Analysis_model(gpu_num,TRAIN_NUM,TEST_NUM,ROUND)#モデルのインスタンス生成
#---------------データ作成 使用するライブラリを選択----------
aModel.data_gen_plain()#データ作成 平文予測攻撃

#---------------計算 使用するライブラリを選択----------------
aModel.learning()#学習 平文予測攻撃

print("Time is "+str(int( time.time()-start ))+"sec" )#経過時間を表示
# Out:
# Let's do a Learning----------------!
# Successfully generated a instance of Cryptographic machine!
# Completed Data_Generating
# Completed Data_Trainslation
# Model for predicting Plain text.
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# WARNING:tensorflow:From /tf/new_key_sche/neural_crypto/analysis_model_plain.py:127: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
#---------------------鍵スケジュール解析 入力データ：最終段鍵スケジュール内部状態---------------------
from analysis_model_keysche import *#鍵スケジュール解析用のライブラリをインポート

#変数など
ROUND=31 #段数
#ROUND=2 #段数
TRAIN_NUM=80000#トレーニングデータ数
TEST_NUM=20000#テストデータ数
gpu_num="0"#使用するGPU

import time
start=time.time()#開始時間

#----------------------計算開始-----------------------------

aModel=Analysis_model(gpu_num,TRAIN_NUM,TEST_NUM,ROUND)#モデルのインスタンス生成
#---------------データ作成 使用するライブラリを選択----------
aModel.data_gen_keyreg()#データ作成 鍵スケジュール解析 最終段鍵スケジュール内部状態

#---------------計算 使用するライブラリを選択----------------
aModel.learning()#学習 鍵スケジュール解析

print("Time is "+str(int( time.time()-start ))+"sec" )#経過時間を表示
# Out:
# Let's do a Learning----------------!
# Successfully generated a instance of Cryptographic machine!
# Completed Data_Generating
# Completed Data_Trainslation
# Model for predicting Plain text.
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/300
# 64000/64000 [==============================] - 1s 8us/sample - loss: 0.2579 - acc: 0.5736 - val_loss: 0.2108 - val_acc: 0.6214
# Epoch 2/300
# 64000/64000 [==============================] - 0s 7us/sample - loss: 0.2021 - acc: 0.6240 - val_loss: 0.1851 - val_acc: 0.6233
# Epoch 3/300
# 64000/64000 [==============================] - 0s 7us/sample - loss: 0.1489 - acc: 0.7356 - val_loss: 0.1062 - val_acc: 0.8443
# Epoch 4/300
# ...

# %%
#---------------------鍵スケジュール解析 入力データ：最終段段鍵---------------------
from analysis_model_keysche import *#鍵スケジュール解析用のライブラリをインポート
#変数など
ROUND=31 #段数
#ROUND=2 #段数
TRAIN_NUM=8000#トレーニングデータ数
TEST_NUM=2000#テストデータ数
gpu_num="0"#使用するGPU

import time
start=time.time()#開始時間

#----------------------計算開始-----------------------------

aModel=Analysis_model(gpu_num,TRAIN_NUM,TEST_NUM,ROUND)#モデルのインスタンス生成
#---------------データ作成 使用するライブラリを選択----------
aModel.data_gen_roundkey()#データ作成 鍵スケジュール解析 最終段段鍵

#---------------計算 使用するライブラリを選択----------------
aModel.learning()#学習 鍵スケジュール解析

print("Time is "+str(int( time.time()-start ))+"sec" )#経過時間を表示
# Out:
# Let's do a Learning----------------!
# Successfully generated a instance of Cryptographic machine!
# Completed Data_Generating
# Completed Data_Trainslation
# Model for predicting Plain text.
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# WARNING:tensorflow:From /tf/new_key_sche/neural_crypto/analysis_model_keysche.py:191: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
